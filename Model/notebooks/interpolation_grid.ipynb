# %% [markdown]
# In this notebook, we will make an interpolation grid that will be used to interpolate 3D fields from the ECCO-Darwin model for use as initial conditions.
#
# In this notebook, we will also confront two new challenges that were not seen in the previous model examples. First, the regional model grid has different depth levels compared to the ECCO grid, so we will also need to interpolate the variables vertically. Second, the grid is at very high latitude, which means we will need to reproject the fields to an appropriate coordinate system before interpolation.
#
# First, import packages to visualize the model fields here:

# %%
# import modules for computation and plotting
import os
import numpy as np
import matplotlib.pyplot as plt
from scipy.interpolate import griddata
from matplotlib.gridspec import GridSpec
import netCDF4 as nc4
#import cmocean.cm as cm

# import pertinent tools from eccoseas
from eccoseas.ecco import pickup
from eccoseas.ecco import grid
from eccoseas.ecco import io
from eccoseas.downscale import horizontal
from eccoseas.downscale import vertical
from eccoseas.toolbox import reprojection
from eccoseas.downscale import interpolation_grid as ecco_interp
# Out:
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.

# %% [markdown]
# ## Motivation for an Interpolation Grid
# For this model, we will use pickup files from the ECCO-Darwin model to construct our initial conditions. In total, we will need to interpolate separate fields: 11 baseline physical variable, 5 sea ice variables, and 37 variable pertaining to the biogeochemistry. Given that the interpolation can be quite slow, especially in areas with a complex coastline that was not represented in the global model, it is advantangeous to first make and store a grid that identifies when and how the interpolation is completed. In other words, we can keep track of where the grid has been interpolated with bilinear interpolation, and locations where a "spreading" routine is used to fill adjacent cells.

# %% [markdown]
# ## Constructing the Interpolation Grid
#
# To construct the interpolation grid, we will proceed in the following steps:
# 1. ensure we have downloaded the necessary ECCO grid files
# 2. read in the ECCO model grid
# 3. read in grid for the regional domain
# 4. prepare the ECCO fields for interpolation
# 5. interpolate the masks vertically
# 6. rerproject the model grid
# 7. create and store the interpolation grid
# 8. visualize the results

# %% [markdown]
# ### Step 1: Download the ECCO Files
# To begin, ensure that all of the necessary pickup and grid files are obtained for this configuration. These are listed on the Overview page for this model.
#
# These files are stored in the following directory:

# %%
data_folder = '/Users/mhwood/Documents/Research/Projects/Chukchi_Sea/Data'

# %% [markdown]
# ### Step 2: Read in the ECCO grid

# %% [markdown]
# Next, we will read in the ECCO grid and convert the grid to tiles. This can be done with functions from the `io` and `grid` modules of **eccoseas**:

# %%
ecco_XC_faces, ecco_YC_faces, ecco_AngleCS_faces, ecco_AngleSN_faces, ecco_hFacC_faces, ecco_hFacW_faces, ecco_hFacS_faces =\
     io.read_ecco_geometry_to_faces(data_folder, llc=270, Nr=50)

# %%
ecco_XC_tiles = grid.ecco_faces_to_tiles(ecco_XC_faces, llc=270, dim=2)
ecco_YC_tiles = grid.ecco_faces_to_tiles(ecco_YC_faces, llc=270, dim=2)
ecco_AngleCS_tiles = grid.ecco_faces_to_tiles(ecco_AngleCS_faces, llc=270, dim=2)
ecco_AngleSN_tiles = grid.ecco_faces_to_tiles(ecco_AngleSN_faces, llc=270, dim=2)
ecco_hFacC_tiles = grid.ecco_faces_to_tiles(ecco_hFacC_faces, llc=270, dim=3)
ecco_hFacS_tiles = grid.ecco_faces_to_tiles(ecco_hFacS_faces, llc=270, dim=3)
ecco_hFacW_tiles = grid.ecco_faces_to_tiles(ecco_hFacW_faces, llc=270, dim=3)
ecco_RF = np.fromfile(os.path.join(data_folder,'RF.data'), '>f4')
ecco_DRF = np.fromfile(os.path.join(data_folder,'DRF.data'), '>f4')

# %%
ecco_Nr = np.size(ecco_DRF)

# %% [markdown]
# ### Step 3: Read in the Regional Model Grid and Mask
# Since the model grid has already been generated for this model (see note on the Model Grid page for this model), we will read it in from the nc file:

# %%
# define the parameters that will be used in the data file
ds = nc4.Dataset(os.path.join(data_folder,'Chukchi_Sea_grid.nc'))
XC = ds.variables['XC'][:, :]
YC = ds.variables['YC'][:, :]
bathy = -1*ds.variables['Depth'][:,:]
AngleCS = ds.variables['AngleCS'][:,:]
AngleSN = ds.variables['AngleSN'][:,:]
hFacC = ds.variables['HFacC'][:, :, :]
hFacW = ds.variables['HFacW'][:, :, :]
hFacS = ds.variables['HFacS'][:, :, :]
delR = ds.variables['drF'][:]
ds.close()
Z = np.cumsum(delR)

# remove the extra row and col from hFacS and hFacW
hFacS = hFacS[:,:-1,:]
hFacW = hFacW[:,:,:-1]

# %% [markdown]
# The mask is generated by setting all of the non-zero `hFac` points to 1:

# %%
maskC = np.copy(hFacC)
maskC[maskC>0] = 1

maskW = np.copy(hFacW)
maskW[maskW>0] = 1

maskS = np.copy(hFacS)
maskS[maskS>0] = 1

# %% [markdown]
# ### Step 4: Prepare the grids for interpolation
# At this point, we can use the geometry of both grids to check to see which tiles have the information we need. By assessing the ECCO grid geometry, we discover that we need tiles 7 and 8:

# %%
# define the tile list
tile_list = [7,8]

# %% [markdown]
# Let's verify that these tiles cover our grid:

# %%
# plot the ECCO tile points
for tile in tile_list:
    plt.plot(ecco_XC_tiles[tile],ecco_YC_tiles[tile],'k.')

# plot the boundary of the regional model
plt.plot(XC[:,0],YC[:,0], 'g-')
plt.plot(XC[:,-1],YC[:,-1], 'g-')
plt.plot(XC[0,:],YC[0,:], 'g-')
plt.plot(XC[-1,:],YC[-1,:], 'g-')

plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.show()

# %% [markdown]
# As we can see, this model boundary (green) is completely surrounded by the points in tile 7 and 8 (black). We also note that there is a lot extraneous information in points outside the regional of our model domain - we will omit these points to speed up our interpolation. Given these observations, now I read in points from just those tiles to use in interpolation:

# %%
# determine the number of points in each set
total_points = 0
for tile_number in tile_list:
    total_points += np.size(ecco_XC_tiles[tile_number])

# make empty arrays to fill in
ecco_XC_points = np.zeros((total_points, ))
ecco_YC_points = np.zeros((total_points, ))
ecco_AngleCS_points = np.zeros((total_points, ))
ecco_AngleSN_points = np.zeros((total_points, ))
ecco_maskC_points = np.zeros((ecco_Nr, total_points))
ecco_maskW_points = np.zeros((ecco_Nr, total_points))
ecco_maskS_points = np.zeros((ecco_Nr, total_points))
ecco_hFacW_points = np.zeros((ecco_Nr, total_points))
ecco_hFacS_points = np.zeros((ecco_Nr, total_points))

# loop through the tiles and fill in the XC, YC, and mask points for interpolation
points_counted = 0
for tile_number in tile_list:
    tile_N = np.size(ecco_XC_tiles[tile_number])
    
    ecco_XC_points[points_counted:points_counted+tile_N] = ecco_XC_tiles[tile_number].ravel()
    ecco_YC_points[points_counted:points_counted+tile_N] = ecco_YC_tiles[tile_number].ravel()

    ecco_AngleCS_points[points_counted:points_counted+tile_N] = ecco_AngleCS_tiles[tile_number].ravel()
    ecco_AngleSN_points[points_counted:points_counted+tile_N] = ecco_AngleSN_tiles[tile_number].ravel()
    
    for k in range(ecco_Nr):
        level_hFacC = ecco_hFacC_tiles[tile_number][k, :, :]
        if tile_number<7:
            level_hFacW = ecco_hFacW_tiles[tile_number][k, :, :]
            level_hFacS = ecco_hFacS_tiles[tile_number][k, :, :]
        else:
            level_hFacS = ecco_hFacW_tiles[tile_number][k, :, :] # these are switched due to the 
            level_hFacW = ecco_hFacS_tiles[tile_number][k, :, :] # assumptions about velocity - see note below
        ecco_hFacW_points[k, points_counted:points_counted+tile_N] = level_hFacW.ravel()
        ecco_hFacS_points[k, points_counted:points_counted+tile_N] = level_hFacS.ravel()
        level_maskC = np.copy(level_hFacC)
        level_maskC[level_maskC>0] = 1
        level_maskW = np.copy(level_hFacW)
        level_maskW[level_maskW>0] = 1
        level_maskS = np.copy(level_hFacS)
        level_maskS[level_maskS>0] = 1
        ecco_maskC_points[k, points_counted:points_counted+tile_N] = level_maskC.ravel()
        ecco_maskW_points[k, points_counted:points_counted+tile_N] = level_maskW.ravel()
        ecco_maskS_points[k, points_counted:points_counted+tile_N] = level_maskS.ravel()
    
    points_counted += tile_N

# wrap the longitude points
ecco_XC_points[ecco_XC_points<0] += 360
print(np.min(ecco_XC_points), np.max(ecco_XC_points))

# remove the points outside the immediate area
local_indices = (ecco_XC_points<250) & (ecco_XC_points>120) & (ecco_YC_points>55) & (ecco_YC_points<80)
ecco_maskC_points = ecco_maskC_points[:, local_indices]
ecco_maskW_points = ecco_maskW_points[:, local_indices]
ecco_maskS_points = ecco_maskS_points[:, local_indices]
ecco_hFacW_points = ecco_hFacW_points[:, local_indices]
ecco_hFacS_points = ecco_hFacS_points[:, local_indices]
ecco_YC_points = ecco_YC_points[local_indices]
ecco_XC_points = ecco_XC_points[local_indices]
# Out:
# 0.011043190719376206 359.9883990673076

# %% [markdown]
# We can double check we have selected the right points by recreating the same plot above:

# %%
# plot the ECCO tile points
plt.plot(ecco_XC_points,ecco_YC_points,'k.')

# plot the boundary of the regional model
plt.plot(XC[:,0],YC[:,0], 'g-')
plt.plot(XC[:,-1],YC[:,-1], 'g-')
plt.plot(XC[0,:],YC[0,:], 'g-')
plt.plot(XC[-1,:],YC[-1,:], 'g-')

plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.show()

# %% [markdown]
# ### Step 5: Interpolate the ECCO mask vertically

# %% [markdown]
# Next, we will address the differences in the vertical grid layers. We can see that they are different by checking their length:

# %%
print('Depth levels in the ECCO grid:',str(np.shape(ecco_DRF)[0]))
print('Depth levels in the regional model grid:',str(np.shape(delR)[0]))
# Out:
# Depth levels in the ECCO grid: 50
# Depth levels in the regional model grid: 90

# %% [markdown]
# And also by plotting these fields vertically:

# %%
fig = plt.figure(figsize=(9,4))

plt.subplot(1,2,1)
plt.plot(ecco_DRF, -1*ecco_RF[:-1], 'k.')
plt.gca().set_ylim([np.max(-1*ecco_RF[:-1]), 0])
plt.title('ECCO Vertical Grid')
plt.ylabel('Depth (m)')
plt.xlabel('Grid Spacing')

plt.subplot(1,2,2)
plt.plot(delR, Z, 'k.')  
plt.gca().set_ylim([np.max(-1*ecco_RF[:-1]), 0])
plt.title('Regional Model Vertical Grid')
plt.xlabel('Grid Spacing (m)')

plt.show()

# %% [markdown]
# To address these differences, we can use the `vertical` module of the **eccoseas** package to interpolate the ECCO mask onto the same vertical grid levels as the regional mask:

# %%
_, ecco_maskC_points_extended = \
    vertical.interpolate_var_grid_faces_to_new_depth_levels(ecco_maskC_points, ecco_maskC_points,
                                                            np.array(ecco_DRF), np.array(delR))

# %% [markdown]
# Let's take a look at the new mask relative to the old one:

# %%
fig = plt.figure(figsize=(9,4))
random_plot_index = 117

plt.subplot(1,2,1)
plt.plot(ecco_maskC_points[:,random_plot_index], -1*ecco_RF[:-1], 'k.')
plt.gca().set_ylim([np.max(-1*ecco_RF[:-1]), 0])
plt.title('Mask on ECCO Vertical Grid\n(length: '+str(np.size(ecco_maskC_points[:,random_plot_index]))+')')
plt.ylabel('Depth (m)')
plt.xlabel('Wet Mask (1=ocean, 0=land)')

plt.subplot(1,2,2)
plt.plot(ecco_maskC_points_extended[:,random_plot_index], Z, 'k.')  
plt.gca().set_ylim([np.max(-1*ecco_RF[:-1]), 0])
plt.title('Mask on Regional Model Vertical Grid\n(length: '+str(np.size(ecco_maskC_points_extended[:,random_plot_index]))+')')
plt.xlabel('Wet Mask (1=ocean, 0=land)')

plt.show()

# %% [markdown]
# Now that our masks are on the same grid levels, we are almost ready to make our interpolation grid.

# %% [markdown]
# ### Step 6: Reprojecting the Model Grid

# %% [markdown]
# Given the location of this model at high latitude, we are going to run into some curious interpolation artefacts if bilinear interpolation is performed using longitude and latitude as coordinates. To demonstrate this issue, let's read in the `Theta` grid from the pickup file and try to interpolate it without reprojecting:

# %%
# read in the global pickup file
global_pickup_faces, global_pickup_metadata = \
    pickup.read_ecco_pickup_file_to_faces(os.path.join(data_folder,'pickup.0000815256'), llc=270)

# convert to tiles
theta_faces = global_pickup_faces['Theta']
theta_tiles = grid.ecco_faces_to_tiles(theta_faces, llc=270, dim=3)

# preprocess like the grid fields
N = np.shape(theta_tiles[1])[-1]*np.shape(theta_tiles[1])[-2]
theta_grid = np.zeros((ecco_Nr, N*len(tile_list)))
points_counted = 0
for tile_number in tile_list:
    for k in range(ecco_Nr):
        theta_grid[k,points_counted:points_counted+N] = \
             theta_tiles[tile_number][k, :, :].ravel()
    points_counted += N
theta_grid = theta_grid[:,local_indices]

# %%
interpolated_theta = horizontal.downscale_3D_points(np.column_stack([ecco_XC_points, ecco_YC_points]),
                                                    theta_grid, ecco_maskC_points_extended, 
                                                    XC, YC, maskC, testing=True, printing=True,
                                                    use_legacy=True, verbose=True)
# Out:
#     Working on level 0 of 50 (354377 nonzero points found)

# %%
plot_grid = np.ma.masked_where(interpolated_theta[0,:,:]==0, interpolated_theta[0,:,:])
C = plt.pcolormesh(plot_grid,vmin=-1.97, vmax=-1.85, cmap='turbo')
plt.colorbar(C, label='Potential Temperature ($^{\circ}$C)')
plt.show()

# %% [markdown]
# Here, we see two problems - first, the interpolation has produced a lot of triangular artefacts resulting from using longitude and latitude as coordinates. We also see some issue with values near the coastline resulting from differing coastlines in the models.
#
# First, let's try reprojecting coordinates to that distances are computed more appropriately for the location. We can do this with the `reprojection` model provided with **eccoseas**:

# %%
utm_zone_epsg = 32602
utm_coordinates = reprojection.reproject_polygon(np.column_stack([ecco_XC_points, ecco_YC_points]), 4326, utm_zone_epsg)

regional_coordinates = reprojection.reproject_polygon(np.column_stack([XC.ravel(), YC.ravel()]), 4326, utm_zone_epsg)
X = regional_coordinates[:,0].reshape(np.shape(XC))
Y = regional_coordinates[:,1].reshape(np.shape(XC))

# %% [markdown]
# When using these coordinates, the triangular artefacts are alleviated:

# %%
interpolated_theta = horizontal.downscale_3D_points(utm_coordinates,
                                                   theta_grid, ecco_maskC_points, 
                                                   X, Y, maskC, 
                                                   testing=True, printing=True)
# Out:
#     Working on level 0 of 50 (354377 nonzero points found)

# %%
plot_grid = np.ma.masked_where(interpolated_theta[0,:,:]==0, interpolated_theta[0,:,:])
C = plt.pcolormesh(plot_grid,vmin=-1.97, vmax=0, cmap='turbo')
plt.colorbar(C, label='Potential Temperature ($^{\circ}$C)')
plt.show()

# %% [markdown]
# Next, for the coastline issue, let's make a land threshold mask to avoid areas which would be wet in the original ECCO grid:

# %%
ecco_maskC_on_regional_domain = np.zeros_like(maskC)
for k in range(np.shape(maskC)[0]):
    ecco_maskC_on_regional_domain[k,:,:] = griddata(utm_coordinates, ecco_maskC_points_extended[k,:], (X, Y), method='nearest')

# %% [markdown]
# Let's take a look:

# %%
plt.figure(figsize=(10,5))
plt.subplot(1,2,1)
plt.pcolormesh(ecco_maskC_on_regional_domain[0,:,:], cmap='Blues')
plt.title('ECCO Wet Grid on Regional Domain\n(surface)')
plt.xlabel('Model Columns')
plt.ylabel('Model Rows')

plt.subplot(1,2,2)
plt.pcolormesh(maskC[0,:,:], cmap='Blues')
plt.title('Regional Domain Wet Grid\n(surface)')
plt.xlabel('Model Columns')

plt.show()

# %% [markdown]
# As we can see, the coastlines are much different. In addition, if any dry cell from ECCO was counted as a wet cell in the interpolation, this 0 value would cause some interpolation artefacts. To alleviate this potential problem, I will apply one additional buffer from the ECCO coastline equal to half the grid cell size in this area:

# %%
threshold = 4e3 # 2 grid cells 
for k in range(np.shape(ecco_maskC_on_regional_domain)[0]):
    print('Working on level '+str(k)
    level = np.ones_like(ecco_maskC_on_regional_domain[k,:,:])
    for p in range(np.shape(utm_coordinates)[0]):
        if ecco_maskC_points[k,p]==0:
            dist = ((utm_coordinates[p,0]-X)**2 + (utm_coordinates[p,1]-Y)**2)**0.5
            level[dist<threshold] = 0
            ecco_maskC_on_regional_domain[k,:,:] =level
ecco_maskC_on_regional_domain
# Out:
# Working on level 0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[79]
#       0 <Error retrieving source code with stack_data see ipython/ipython#13598>
#
# KeyboardInterrupt:

# %% [markdown]
# The final mask for the ECCO grid looks as follows:

# %%
plt.figure(figsize=(10,5))
plt.subplot(1,2,1)
plt.pcolormesh(ecco_maskC_on_regional_domain[10,:,:], cmap='Blues')
plt.title('ECCO Wet Grid on Regional Domain\n(surface)')
plt.xlabel('Model Columns')
plt.ylabel('Model Rows')

plt.subplot(1,2,2)
plt.pcolormesh(maskC[10,:,:], cmap='Blues')
plt.title('Regional Domain Wet Grid\n(surface)')
plt.xlabel('Model Columns')

plt.show()

# %% [markdown]
# With this mask, the coastline values will be more sensibly filled:

# %%
interpolated_theta = horizontal.downscale_3D_points(utm_coordinates,
                                                   theta_grid, ecco_maskC_points, 
                                                   X, Y, maskC, maskC,
                                                   testing=True, printing=True)
# Out:
#     Working on level 0 of 50 (354377 nonzero points found)

# %%
plot_grid = np.ma.masked_where(interpolated_theta[0,:,:]==0, interpolated_theta[0,:,:])
C = plt.pcolormesh(plot_grid,vmin=-1.97, vmax=-1.85, cmap='turbo')
plt.colorbar(C, label='Potential Temperature ($^{\circ}$C)')
plt.show()

# %% [markdown]
# ### Step 7: Creating the Interpolation Grid

# %% [markdown]
# Finally, with the grid read in, interpolated to the same vertical levels, and reprojected to a sensible coordinate system, we can create our interpolation grid:

# %%
gridC, gridS, gridW = \
ecco_interp.create_interpolation_grids(utm_coordinates[:,0], utm_coordinates[:,1],
                           ecco_maskC_points_extended, maskC,
                           X, Y, maskC, maskS, maskW,
                           testing=False, printing=True)
# Out:
#  - Working on level 0 of 90 (354377 nonzero points found)
#    - Remaining points before horizontal spread: 0
#    - Remaining points before downward spread: 0
#  - Working on level 1 of 90 (354377 nonzero points found)
#    - Remaining points before horizontal spread: 0
#    - Remaining points before downward spread: 0
#  - Working on level 2 of 90 (354377 nonzero points found)
#    - Remaining points before horizontal spread: 0
#    - Remaining points before downward spread: 0
#  - Working on level 3 of 90 (354377 nonzero points found)
#    - Remaining points before horizontal spread: 0
#    - Remaining points before downward spread: 0
#  - Working on level 4 of 90 (354377 nonzero points found)
#    - Remaining points before horizontal spread: 0
#    - Remaining points before downward spread: 0
#  - Working on level 5 of 90 (354377 nonzero points found)
#    - Remaining points before horizontal spread: 0
#    - Remaining points before downward spread: 0
#  - Working on level 6 of 90 (354377 nonzero points found)
#    - Remaining points before horizontal spread: 0
#    - Remaining points before downward spread: 0
#  - Working on level 7 of 90 (336094 nonzero points found)
#    - Remaining points before horizontal spread: 0
#    - Remaining points before downward spread: 0
#  - Working on level 8 of 90 (331277 nonzero points found)
#    - Remaining points before horizontal spread: 0
#    - Remaining points before downward spread: 0
#  - Working on level 9 of 90 (321570 nonzero points found)
#    - Remaining points before horizontal spread: 0
#    - Remaining points before downward spread: 0
#  - Working on level 10 of 90 (307338 nonzero points found)
#    - Remaining points before horizontal spread: 0
#    - Remaining points before downward spread: 0
#  - Working on level 11 of 90 (295942 nonzero points found)
#    - Remaining points before horizontal spread: 0
#    - Remaining points before downward spread: 0
#  - Working on level 12 of 90 (274810 nonzero points found)
#    - Remaining points before horizontal spread: 0
#    - Remaining points before downward spread: 0
#  - Working on level 13 of 90 (253228 nonzero points found)
#    - Remaining points before horizontal spread: 0
#    - Remaining points before downward spread: 0
#  - Working on level 14 of 90 (229040 nonzero points found)
#    - Remaining points before horizontal spread: 0
#    - Remaining points before downward spread: 0
#  - Working on level 15 of 90 (187878 nonzero points found)
#    - Remaining points before horizontal spread: 0
#    - Remaining points before downward spread: 0
#  - Working on level 16 of 90 (136242 nonzero points found)
#    - Remaining points before horizontal spread: 0
#    - Remaining points before downward spread: 0
#  - Working on level 17 of 90 (106660 nonzero points found)
#    - Remaining points before horizontal spread: 0
#    - Remaining points before downward spread: 0
#  - Working on level 18 of 90 (94346 nonzero points found)
#    - Remaining points before horizontal spread: 0
#    - Remaining points before downward spread: 0
#  - Working on level 19 of 90 (82737 nonzero points found)
#    - Remaining points before horizontal spread: 0
#    - Remaining points before downward spread: 0
#  - Working on level 20 of 90 (70337 nonzero points found)
#    - Remaining points before horizontal spread: 0
#    - Remaining points before downward spread: 0
#  - Working on level 21 of 90 (60366 nonzero points found)
#    - Remaining points before horizontal spread: 0
#    - Remaining points before downward spread: 0
#  - Working on level 22 of 90 (54675 nonzero points found)
#    - Remaining points before horizontal spread: 0
#    - Remaining points before downward spread: 0
#  - Working on level 23 of 90 (50727 nonzero points found)
#    - Remaining points before horizontal spread: 0
#    - Remaining points before downward spread: 0
#  - Working on level 24 of 90 (47111 nonzero points found)
#    - Remaining points before horizontal spread: 0
#    - Remaining points before downward spread: 0
#  - Working on level 25 of 90 (43530 nonzero points found)
#    - Remaining points before horizontal spread: 0
#    - Remaining points before downward spread: 0
#  - Working on level 26 of 90 (40125 nonzero points found)
#    - Remaining points before horizontal spread: 0
#    - Remaining points before downward spread: 0
#  - Working on level 27 of 90 (37266 nonzero points found)
#    - Remaining points before horizontal spread: 0
#    - Remaining points before downward spread: 0
#  - Working on level 28 of 90 (35168 nonzero points found)
#    - Remaining points before horizontal spread: 0
#    - Remaining points before downward spread: 0
#  - Working on level 29 of 90 (33941 nonzero points found)
#    - Remaining points before horizontal spread: 0
#    - Remaining points before downward spread: 0
#  - Working on level 30 of 90 (33069 nonzero points found)
#    - Remaining points before horizontal spread: 0
#    - Remaining points before downward spread: 0
#  - Working on level 31 of 90 (32422 nonzero points found)
#    - Remaining points before horizontal spread: 0
#    - Remaining points before downward spread: 0
#  - Working on level 32 of 90 (31879 nonzero points found)
#    - Remaining points before horizontal spread: 0
#    - Remaining points before downward spread: 0
#  - Working on level 33 of 90 (31277 nonzero points found)
#    - Remaining points before horizontal spread: 0
#    - Remaining points before downward spread: 0
#  - Working on level 34 of 90 (30803 nonzero points found)
#    - Remaining points before horizontal spread: 0
#    - Remaining points before downward spread: 0
#  - Working on level 35 of 90 (30365 nonzero points found)
#    - Remaining points before horizontal spread: 0
#    - Remaining points before downward spread: 0
#  - Working on level 36 of 90 (30007 nonzero points found)
#    - Remaining points before horizontal spread: 0
#    - Remaining points before downward spread: 0
#  - Working on level 37 of 90 (29698 nonzero points found)
#    - Remaining points before horizontal spread: 0
#    - Remaining points before downward spread: 0
#  - Working on level 38 of 90 (29430 nonzero points found)
#    - Remaining points before horizontal spread: 0
#    - Remaining points before downward spread: 0
#  - Working on level 39 of 90 (29200 nonzero points found)
#    - Remaining points before horizontal spread: 0
#    - Remaining points before downward spread: 0
#  - Working on level 40 of 90 (29008 nonzero points found)
#    - Remaining points before horizontal spread: 0
#    - Remaining points before downward spread: 0
#  - Working on level 41 of 90 (28811 nonzero points found)
#    - Remaining points before horizontal spread: 0
#    - Remaining points before downward spread: 0
#  - Working on level 42 of 90 (28622 nonzero points found)
#    - Remaining points before horizontal spread: 0
#    - Remaining points before downward spread: 0
#  - Working on level 43 of 90 (28435 nonzero points found)
#    - Remaining points before horizontal spread: 0
#    - Remaining points before downward spread: 0
#  - Working on level 44 of 90 (28267 nonzero points found)
#    - Remaining points before horizontal spread: 0
#    - Remaining points before downward spread: 0
#  - Working on level 45 of 90 (28073 nonzero points found)
#    - Remaining points before horizontal spread: 0
#    - Remaining points before downward spread: 0
#  - Working on level 46 of 90 (27915 nonzero points found)
#    - Remaining points before horizontal spread: 0
#    - Remaining points before downward spread: 0
#  - Working on level 47 of 90 (27755 nonzero points found)
#    - Remaining points before horizontal spread: 0
#    - Remaining points before downward spread: 0
#  - Working on level 48 of 90 (27576 nonzero points found)
#    - Remaining points before horizontal spread: 0
#    - Remaining points before downward spread: 0
#  - Working on level 49 of 90 (27389 nonzero points found)
#    - Remaining points before horizontal spread: 0
#    - Remaining points before downward spread: 0
#  - Working on level 50 of 90 (27176 nonzero points found)
#    - Remaining points before horizontal spread: 0
#    - Remaining points before downward spread: 0
#  - Working on level 51 of 90 (26961 nonzero points found)
#    - Remaining points before horizontal spread: 0
#    - Remaining points before downward spread: 0
#  - Working on level 52 of 90 (26729 nonzero points found)
#    - Remaining points before horizontal spread: 0
#    - Remaining points before downward spread: 0
#  - Working on level 53 of 90 (26481 nonzero points found)
#    - Remaining points before horizontal spread: 0
#    - Remaining points before downward spread: 0
#  - Working on level 54 of 90 (26207 nonzero points found)
#    - Remaining points before horizontal spread: 0
#    - Remaining points before downward spread: 0
#  - Working on level 55 of 90 (25962 nonzero points found)
#    - Remaining points before horizontal spread: 0
#    - Remaining points before downward spread: 0
#  - Working on level 56 of 90 (25666 nonzero points found)
#    - Remaining points before horizontal spread: 0
#    - Remaining points before downward spread: 0
#  - Working on level 57 of 90 (25367 nonzero points found)
#    - Remaining points before horizontal spread: 0
#    - Remaining points before downward spread: 0
#  - Working on level 58 of 90 (25045 nonzero points found)
#    - Remaining points before horizontal spread: 0
#    - Remaining points before downward spread: 0
#  - Working on level 59 of 90 (24702 nonzero points found)
#    - Remaining points before horizontal spread: 0
#    - Remaining points before downward spread: 0
#  - Working on level 60 of 90 (24349 nonzero points found)
#    - Remaining points before horizontal spread: 0
#    - Remaining points before downward spread: 0
#  - Working on level 61 of 90 (23970 nonzero points found)
#    - Remaining points before horizontal spread: 0
#    - Remaining points before downward spread: 0
#  - Working on level 62 of 90 (23555 nonzero points found)
#    - Remaining points before horizontal spread: 0
#    - Remaining points before downward spread: 0
#  - Working on level 63 of 90 (23109 nonzero points found)
#    - Remaining points before horizontal spread: 0
#    - Remaining points before downward spread: 0
#  - Working on level 64 of 90 (22607 nonzero points found)
#    - Remaining points before horizontal spread: 0
#    - Remaining points before downward spread: 0
#  - Working on level 65 of 90 (22039 nonzero points found)
#    - Remaining points before horizontal spread: 0
#    - Remaining points before downward spread: 0
#  - Working on level 66 of 90 (21465 nonzero points found)
#    - Remaining points before horizontal spread: 0
#    - Remaining points before downward spread: 0
#  - Working on level 67 of 90 (20848 nonzero points found)
#    - Remaining points before horizontal spread: 0
#    - Remaining points before downward spread: 0
#  - Working on level 68 of 90 (20243 nonzero points found)
#    - Remaining points before horizontal spread: 0
#    - Remaining points before downward spread: 0
#  - Working on level 69 of 90 (19570 nonzero points found)
#    - Remaining points before horizontal spread: 0
#    - Remaining points before downward spread: 0
#  - Working on level 70 of 90 (18885 nonzero points found)
#    - Remaining points before horizontal spread: 0
#    - Remaining points before downward spread: 0
#  - Working on level 71 of 90 (18185 nonzero points found)
#    - Remaining points before horizontal spread: 0
#    - Remaining points before downward spread: 0
#  - Working on level 72 of 90 (17349 nonzero points found)
#    - Remaining points before horizontal spread: 0
#    - Remaining points before downward spread: 0
#  - Working on level 73 of 90 (16507 nonzero points found)
#    - Remaining points before horizontal spread: 0
#    - Remaining points before downward spread: 0
#  - Working on level 74 of 90 (15625 nonzero points found)
#    - Remaining points before horizontal spread: 0
#    - Remaining points before downward spread: 0
#  - Working on level 75 of 90 (14635 nonzero points found)
#    - Remaining points before horizontal spread: 0
#    - Remaining points before downward spread: 0
#  - Working on level 76 of 90 (13527 nonzero points found)
#    - Remaining points before horizontal spread: 0
#    - Remaining points before downward spread: 0
#  - Working on level 77 of 90 (12229 nonzero points found)
#    - Remaining points before horizontal spread: 0
#    - Remaining points before downward spread: 0
#  - Working on level 78 of 90 (10676 nonzero points found)
#    - Remaining points before horizontal spread: 0
#    - Remaining points before downward spread: 0
#  - Working on level 79 of 90 (7935 nonzero points found)
#    - Remaining points before horizontal spread: 0
#    - Remaining points before downward spread: 0
#  - Working on level 80 of 90 (4206 nonzero points found)
#    - Remaining points before horizontal spread: 0
#    - Remaining points before downward spread: 0
#  - Working on level 81 of 90 (1 nonzero points found)
#    - Remaining points before horizontal spread: 0
#    - Remaining points before downward spread: 0
#  - Working on level 0 of 90 (352513 nonzero points found)
#    - Remaining points before horizontal spread: 0
#    - Remaining points before downward spread: 0
#  - Working on level 1 of 90 (352513 nonzero points found)
#    - Remaining points before horizontal spread: 0
#    - Remaining points before downward spread: 0
#  - Working on level 2 of 90 (352513 nonzero points found)
#    - Remaining points before horizontal spread: 0
#    - Remaining points before downward spread: 0
#  - Working on level 3 of 90 (352513 nonzero points found)
#    - Remaining points before horizontal spread: 0
#    - Remaining points before downward spread: 0
#  - Working on level 4 of 90 (352513 nonzero points found)
#    - Remaining points before horizontal spread: 0
#    - Remaining points before downward spread: 0
#  - Working on level 5 of 90 (352513 nonzero points found)
#    - Remaining points before horizontal spread: 0
#    - Remaining points before downward spread: 0
#  - Working on level 6 of 90 (352513 nonzero points found)
#    - Remaining points before horizontal spread: 0
#    - Remaining points before downward spread: 0
#  - Working on level 7 of 90 (334288 nonzero points found)
#    - Remaining points before horizontal spread: 0
#    - Remaining points before downward spread: 0
#  - Working on level 8 of 90 (329382 nonzero points found)
#    - Remaining points before horizontal spread: 0
#    - Remaining points before downward spread: 0
#  - Working on level 9 of 90 (319345 nonzero points found)
#    - Remaining points before horizontal spread: 0
#    - Remaining points before downward spread: 0
#  - Working on level 10 of 90 (305127 nonzero points found)
#    - Remaining points before horizontal spread: 0
#    - Remaining points before downward spread: 0
#  - Working on level 11 of 90 (293726 nonzero points found)
#    - Remaining points before horizontal spread: 0
#    - Remaining points before downward spread: 0
#  - Working on level 12 of 90 (272278 nonzero points found)
#    - Remaining points before horizontal spread: 0
#    - Remaining points before downward spread: 0
#  - Working on level 13 of 90 (250587 nonzero points found)
#    - Remaining points before horizontal spread: 0
#    - Remaining points before downward spread: 0
#  - Working on level 14 of 90 (226314 nonzero points found)
#    - Remaining points before horizontal spread: 0
#    - Remaining points before downward spread: 0
#  - Working on level 15 of 90 (184736 nonzero points found)
#    - Remaining points before horizontal spread: 0
#    - Remaining points before downward spread: 0
#  - Working on level 16 of 90 (133410 nonzero points found)
#    - Remaining points before horizontal spread: 0
#    - Remaining points before downward spread: 0
#  - Working on level 17 of 90 (104881 nonzero points found)
#    - Remaining points before horizontal spread: 0
#    - Remaining points before downward spread: 0
#  - Working on level 18 of 90 (92696 nonzero points found)
#    - Remaining points before horizontal spread: 0
#    - Remaining points before downward spread: 0
#  - Working on level 19 of 90 (81198 nonzero points found)
#    - Remaining points before horizontal spread: 0
#    - Remaining points before downward spread: 0
#  - Working on level 20 of 90 (68916 nonzero points found)
#    - Remaining points before horizontal spread: 0
#    - Remaining points before downward spread: 0
#  - Working on level 21 of 90 (59096 nonzero points found)
#    - Remaining points before horizontal spread: 0
#    - Remaining points before downward spread: 0
#  - Working on level 22 of 90 (53543 nonzero points found)
#    - Remaining points before horizontal spread: 0
#    - Remaining points before downward spread: 0
#  - Working on level 23 of 90 (49697 nonzero points found)
#    - Remaining points before horizontal spread: 0
#    - Remaining points before downward spread: 0
#  - Working on level 24 of 90 (46122 nonzero points found)
#    - Remaining points before horizontal spread: 0
#    - Remaining points before downward spread: 0
#  - Working on level 25 of 90 (42533 nonzero points found)
#    - Remaining points before horizontal spread: 0
#    - Remaining points before downward spread: 0
#  - Working on level 26 of 90 (39195 nonzero points found)
#    - Remaining points before horizontal spread: 0
#    - Remaining points before downward spread: 0
#  - Working on level 27 of 90 (36417 nonzero points found)
#    - Remaining points before horizontal spread: 0
#    - Remaining points before downward spread: 0
#  - Working on level 28 of 90 (34412 nonzero points found)
#    - Remaining points before horizontal spread: 0
#    - Remaining points before downward spread: 0
#  - Working on level 29 of 90 (33257 nonzero points found)
#    - Remaining points before horizontal spread: 0
#    - Remaining points before downward spread: 0
#  - Working on level 30 of 90 (32429 nonzero points found)
#    - Remaining points before horizontal spread: 0
#    - Remaining points before downward spread: 0
#  - Working on level 31 of 90 (31816 nonzero points found)
#    - Remaining points before horizontal spread: 0
#    - Remaining points before downward spread: 0
#  - Working on level 32 of 90 (31285 nonzero points found)
#    - Remaining points before horizontal spread: 0
#    - Remaining points before downward spread: 0
#  - Working on level 33 of 90 (30695 nonzero points found)
#    - Remaining points before horizontal spread: 0
#    - Remaining points before downward spread: 0
#  - Working on level 34 of 90 (30233 nonzero points found)
#    - Remaining points before horizontal spread: 0
#    - Remaining points before downward spread: 0
#  - Working on level 35 of 90 (29805 nonzero points found)
#    - Remaining points before horizontal spread: 0
#    - Remaining points before downward spread: 0
#  - Working on level 36 of 90 (29455 nonzero points found)
#    - Remaining points before horizontal spread: 0
#    - Remaining points before downward spread: 0
#  - Working on level 37 of 90 (29155 nonzero points found)
#    - Remaining points before horizontal spread: 0
#    - Remaining points before downward spread: 0
#  - Working on level 38 of 90 (28895 nonzero points found)
#    - Remaining points before horizontal spread: 0
#    - Remaining points before downward spread: 0
#  - Working on level 39 of 90 (28668 nonzero points found)
#    - Remaining points before horizontal spread: 0
#    - Remaining points before downward spread: 0
#  - Working on level 40 of 90 (28479 nonzero points found)
#    - Remaining points before horizontal spread: 0
#    - Remaining points before downward spread: 0
#  - Working on level 41 of 90 (28281 nonzero points found)
#    - Remaining points before horizontal spread: 0
#    - Remaining points before downward spread: 0
#  - Working on level 42 of 90 (28092 nonzero points found)
#    - Remaining points before horizontal spread: 0
#    - Remaining points before downward spread: 0
#  - Working on level 43 of 90 (27904 nonzero points found)
#    - Remaining points before horizontal spread: 0
#    - Remaining points before downward spread: 0
#  - Working on level 44 of 90 (27732 nonzero points found)
#    - Remaining points before horizontal spread: 0
#    - Remaining points before downward spread: 0
#  - Working on level 45 of 90 (27542 nonzero points found)
#    - Remaining points before horizontal spread: 0
#    - Remaining points before downward spread: 0
#  - Working on level 46 of 90 (27384 nonzero points found)
#    - Remaining points before horizontal spread: 0
#    - Remaining points before downward spread: 0
#  - Working on level 47 of 90 (27225 nonzero points found)
#    - Remaining points before horizontal spread: 0
#    - Remaining points before downward spread: 0
#  - Working on level 48 of 90 (27046 nonzero points found)
#    - Remaining points before horizontal spread: 0
#    - Remaining points before downward spread: 0
#  - Working on level 49 of 90 (26856 nonzero points found)
#    - Remaining points before horizontal spread: 0
#    - Remaining points before downward spread: 0
#  - Working on level 50 of 90 (26639 nonzero points found)
#    - Remaining points before horizontal spread: 0
#    - Remaining points before downward spread: 0
#  - Working on level 51 of 90 (26421 nonzero points found)
#    - Remaining points before horizontal spread: 0
#    - Remaining points before downward spread: 0
#  - Working on level 52 of 90 (26188 nonzero points found)
#    - Remaining points before horizontal spread: 0
#    - Remaining points before downward spread: 0
#  - Working on level 53 of 90 (25936 nonzero points found)
#    - Remaining points before horizontal spread: 0
#    - Remaining points before downward spread: 0
#  - Working on level 54 of 90 (25657 nonzero points found)
#    - Remaining points before horizontal spread: 0
#    - Remaining points before downward spread: 0
#  - Working on level 55 of 90 (25409 nonzero points found)
#    - Remaining points before horizontal spread: 0
#    - Remaining points before downward spread: 0
#  - Working on level 56 of 90 (25118 nonzero points found)
#    - Remaining points before horizontal spread: 0
#    - Remaining points before downward spread: 0
#  - Working on level 57 of 90 (24811 nonzero points found)
#    - Remaining points before horizontal spread: 0
#    - Remaining points before downward spread: 0
#  - Working on level 58 of 90 (24484 nonzero points found)
#    - Remaining points before horizontal spread: 0
#    - Remaining points before downward spread: 0
#  - Working on level 59 of 90 (24144 nonzero points found)
#    - Remaining points before horizontal spread: 0
#    - Remaining points before downward spread: 0
#  - Working on level 60 of 90 (23797 nonzero points found)
#    - Remaining points before horizontal spread: 0
#    - Remaining points before downward spread: 0
#  - Working on level 61 of 90 (23415 nonzero points found)
#    - Remaining points before horizontal spread: 0
#    - Remaining points before downward spread: 0
#  - Working on level 62 of 90 (23014 nonzero points found)
#    - Remaining points before horizontal spread: 0
#    - Remaining points before downward spread: 0
#  - Working on level 63 of 90 (22572 nonzero points found)
#    - Remaining points before horizontal spread: 0
#    - Remaining points before downward spread: 0
#  - Working on level 64 of 90 (22074 nonzero points found)
#    - Remaining points before horizontal spread: 0
#    - Remaining points before downward spread: 0
#  - Working on level 65 of 90 (21519 nonzero points found)
#    - Remaining points before horizontal spread: 0
#    - Remaining points before downward spread: 0
#  - Working on level 66 of 90 (20957 nonzero points found)
#    - Remaining points before horizontal spread: 0
#    - Remaining points before downward spread: 0
#  - Working on level 67 of 90 (20347 nonzero points found)
#    - Remaining points before horizontal spread: 0
#    - Remaining points before downward spread: 0
#  - Working on level 68 of 90 (19765 nonzero points found)
#    - Remaining points before horizontal spread: 0
#    - Remaining points before downward spread: 0
#  - Working on level 69 of 90 (19109 nonzero points found)
#    - Remaining points before horizontal spread: 0
#    - Remaining points before downward spread: 0
#  - Working on level 70 of 90 (18455 nonzero points found)
#    - Remaining points before horizontal spread: 0
#    - Remaining points before downward spread: 0
#  - Working on level 71 of 90 (17773 nonzero points found)
#    - Remaining points before horizontal spread: 0
#    - Remaining points before downward spread: 0
#  - Working on level 72 of 90 (16954 nonzero points found)
#    - Remaining points before horizontal spread: 0
#    - Remaining points before downward spread: 0
#  - Working on level 73 of 90 (16121 nonzero points found)
#    - Remaining points before horizontal spread: 0
#    - Remaining points before downward spread: 0
#  - Working on level 74 of 90 (15265 nonzero points found)
#    - Remaining points before horizontal spread: 0
#    - Remaining points before downward spread: 0
#  - Working on level 75 of 90 (14303 nonzero points found)
#    - Remaining points before horizontal spread: 0
#    - Remaining points before downward spread: 0
#  - Working on level 76 of 90 (13214 nonzero points found)
#    - Remaining points before horizontal spread: 0
#    - Remaining points before downward spread: 0
#  - Working on level 77 of 90 (11956 nonzero points found)
#    - Remaining points before horizontal spread: 0
#    - Remaining points before downward spread: 0
#  - Working on level 78 of 90 (10394 nonzero points found)
#    - Remaining points before horizontal spread: 0
#    - Remaining points before downward spread: 0
#  - Working on level 79 of 90 (7683 nonzero points found)
#    - Remaining points before horizontal spread: 0
#    - Remaining points before downward spread: 0
#  - Working on level 80 of 90 (4017 nonzero points found)
#    - Remaining points before horizontal spread: 0
#    - Remaining points before downward spread: 0
#  - Working on level 0 of 90 (352828 nonzero points found)
#    - Remaining points before horizontal spread: 0
#    - Remaining points before downward spread: 0
#  - Working on level 1 of 90 (352828 nonzero points found)
#    - Remaining points before horizontal spread: 0
#    - Remaining points before downward spread: 0
#  - Working on level 2 of 90 (352828 nonzero points found)
#    - Remaining points before horizontal spread: 0
#    - Remaining points before downward spread: 0
#  - Working on level 3 of 90 (352828 nonzero points found)
#    - Remaining points before horizontal spread: 0
#    - Remaining points before downward spread: 0
#  - Working on level 4 of 90 (352828 nonzero points found)
#    - Remaining points before horizontal spread: 0
#    - Remaining points before downward spread: 0
#  - Working on level 5 of 90 (352828 nonzero points found)
#    - Remaining points before horizontal spread: 0
#    - Remaining points before downward spread: 0
#  - Working on level 6 of 90 (352828 nonzero points found)
#    - Remaining points before horizontal spread: 0
#    - Remaining points before downward spread: 0
#  - Working on level 7 of 90 (334514 nonzero points found)
#    - Remaining points before horizontal spread: 0
#    - Remaining points before downward spread: 0
#  - Working on level 8 of 90 (329615 nonzero points found)
#    - Remaining points before horizontal spread: 0
#    - Remaining points before downward spread: 0
#  - Working on level 9 of 90 (319601 nonzero points found)
#    - Remaining points before horizontal spread: 0
#    - Remaining points before downward spread: 0
#  - Working on level 10 of 90 (305455 nonzero points found)
#    - Remaining points before horizontal spread: 0
#    - Remaining points before downward spread: 0
#  - Working on level 11 of 90 (294027 nonzero points found)
#    - Remaining points before horizontal spread: 0
#    - Remaining points before downward spread: 0
#  - Working on level 12 of 90 (272542 nonzero points found)
#    - Remaining points before horizontal spread: 0
#    - Remaining points before downward spread: 0
#  - Working on level 13 of 90 (250940 nonzero points found)
#    - Remaining points before horizontal spread: 0
#    - Remaining points before downward spread: 0
#  - Working on level 14 of 90 (226638 nonzero points found)
#    - Remaining points before horizontal spread: 0
#    - Remaining points before downward spread: 0
#  - Working on level 15 of 90 (184916 nonzero points found)
#    - Remaining points before horizontal spread: 0
#    - Remaining points before downward spread: 0
#  - Working on level 16 of 90 (133542 nonzero points found)
#    - Remaining points before horizontal spread: 0
#    - Remaining points before downward spread: 0
#  - Working on level 17 of 90 (105229 nonzero points found)
#    - Remaining points before horizontal spread: 0
#    - Remaining points before downward spread: 0
#  - Working on level 18 of 90 (93091 nonzero points found)
#    - Remaining points before horizontal spread: 0
#    - Remaining points before downward spread: 0
#  - Working on level 19 of 90 (81617 nonzero points found)
#    - Remaining points before horizontal spread: 0
#    - Remaining points before downward spread: 0
#  - Working on level 20 of 90 (69392 nonzero points found)
#    - Remaining points before horizontal spread: 0
#    - Remaining points before downward spread: 0
#  - Working on level 21 of 90 (59705 nonzero points found)
#    - Remaining points before horizontal spread: 0
#    - Remaining points before downward spread: 0
#  - Working on level 22 of 90 (54172 nonzero points found)
#    - Remaining points before horizontal spread: 0
#    - Remaining points before downward spread: 0
#  - Working on level 23 of 90 (50295 nonzero points found)
#    - Remaining points before horizontal spread: 0
#    - Remaining points before downward spread: 0
#  - Working on level 24 of 90 (46700 nonzero points found)
#    - Remaining points before horizontal spread: 0
#    - Remaining points before downward spread: 0
#  - Working on level 25 of 90 (43094 nonzero points found)
#    - Remaining points before horizontal spread: 0
#    - Remaining points before downward spread: 0
#  - Working on level 26 of 90 (39745 nonzero points found)
#    - Remaining points before horizontal spread: 0
#    - Remaining points before downward spread: 0
#  - Working on level 27 of 90 (36919 nonzero points found)
#    - Remaining points before horizontal spread: 0
#    - Remaining points before downward spread: 0
#  - Working on level 28 of 90 (34860 nonzero points found)
#    - Remaining points before horizontal spread: 0
#    - Remaining points before downward spread: 0
#  - Working on level 29 of 90 (33678 nonzero points found)
#    - Remaining points before horizontal spread: 0
#    - Remaining points before downward spread: 0
#  - Working on level 30 of 90 (32814 nonzero points found)
#    - Remaining points before horizontal spread: 0
#    - Remaining points before downward spread: 0
#  - Working on level 31 of 90 (32185 nonzero points found)
#    - Remaining points before horizontal spread: 0
#    - Remaining points before downward spread: 0
#  - Working on level 32 of 90 (31633 nonzero points found)
#    - Remaining points before horizontal spread: 0
#    - Remaining points before downward spread: 0
#  - Working on level 33 of 90 (31047 nonzero points found)
#    - Remaining points before horizontal spread: 0
#    - Remaining points before downward spread: 0
#  - Working on level 34 of 90 (30583 nonzero points found)
#    - Remaining points before horizontal spread: 0
#    - Remaining points before downward spread: 0
#  - Working on level 35 of 90 (30140 nonzero points found)
#    - Remaining points before horizontal spread: 0
#    - Remaining points before downward spread: 0
#  - Working on level 36 of 90 (29775 nonzero points found)
#    - Remaining points before horizontal spread: 0
#    - Remaining points before downward spread: 0
#  - Working on level 37 of 90 (29468 nonzero points found)
#    - Remaining points before horizontal spread: 0
#    - Remaining points before downward spread: 0
#  - Working on level 38 of 90 (29193 nonzero points found)
#    - Remaining points before horizontal spread: 0
#    - Remaining points before downward spread: 0
#  - Working on level 39 of 90 (28958 nonzero points found)
#    - Remaining points before horizontal spread: 0
#    - Remaining points before downward spread: 0
#  - Working on level 40 of 90 (28761 nonzero points found)
#    - Remaining points before horizontal spread: 0
#    - Remaining points before downward spread: 0
#  - Working on level 41 of 90 (28554 nonzero points found)
#    - Remaining points before horizontal spread: 0
#    - Remaining points before downward spread: 0
#  - Working on level 42 of 90 (28359 nonzero points found)
#    - Remaining points before horizontal spread: 0
#    - Remaining points before downward spread: 0
#  - Working on level 43 of 90 (28169 nonzero points found)
#    - Remaining points before horizontal spread: 0
#    - Remaining points before downward spread: 0
#  - Working on level 44 of 90 (27996 nonzero points found)
#    - Remaining points before horizontal spread: 0
#    - Remaining points before downward spread: 0
#  - Working on level 45 of 90 (27806 nonzero points found)
#    - Remaining points before horizontal spread: 0
#    - Remaining points before downward spread: 0
#  - Working on level 46 of 90 (27646 nonzero points found)
#    - Remaining points before horizontal spread: 0
#    - Remaining points before downward spread: 0
#  - Working on level 47 of 90 (27477 nonzero points found)
#    - Remaining points before horizontal spread: 0
#    - Remaining points before downward spread: 0
#  - Working on level 48 of 90 (27293 nonzero points found)
#    - Remaining points before horizontal spread: 0
#    - Remaining points before downward spread: 0
#  - Working on level 49 of 90 (27098 nonzero points found)
#    - Remaining points before horizontal spread: 0
#    - Remaining points before downward spread: 0
#  - Working on level 50 of 90 (26878 nonzero points found)
#    - Remaining points before horizontal spread: 0
#    - Remaining points before downward spread: 0
#  - Working on level 51 of 90 (26656 nonzero points found)
#    - Remaining points before horizontal spread: 0
#    - Remaining points before downward spread: 0
#  - Working on level 52 of 90 (26418 nonzero points found)
#    - Remaining points before horizontal spread: 0
#    - Remaining points before downward spread: 0
#  - Working on level 53 of 90 (26153 nonzero points found)
#    - Remaining points before horizontal spread: 0
#    - Remaining points before downward spread: 0
#  - Working on level 54 of 90 (25869 nonzero points found)
#    - Remaining points before horizontal spread: 0
#    - Remaining points before downward spread: 0
#  - Working on level 55 of 90 (25617 nonzero points found)
#    - Remaining points before horizontal spread: 0
#    - Remaining points before downward spread: 0
#  - Working on level 56 of 90 (25314 nonzero points found)
#    - Remaining points before horizontal spread: 0
#    - Remaining points before downward spread: 0
#  - Working on level 57 of 90 (25006 nonzero points found)
#    - Remaining points before horizontal spread: 0
#    - Remaining points before downward spread: 0
#  - Working on level 58 of 90 (24674 nonzero points found)
#    - Remaining points before horizontal spread: 0
#    - Remaining points before downward spread: 0
#  - Working on level 59 of 90 (24323 nonzero points found)
#    - Remaining points before horizontal spread: 0
#    - Remaining points before downward spread: 0
#  - Working on level 60 of 90 (23965 nonzero points found)
#    - Remaining points before horizontal spread: 0
#    - Remaining points before downward spread: 0
#  - Working on level 61 of 90 (23586 nonzero points found)
#    - Remaining points before horizontal spread: 0
#    - Remaining points before downward spread: 0
#  - Working on level 62 of 90 (23157 nonzero points found)
#    - Remaining points before horizontal spread: 0
#    - Remaining points before downward spread: 0
#  - Working on level 63 of 90 (22715 nonzero points found)
#    - Remaining points before horizontal spread: 0
#    - Remaining points before downward spread: 0
#  - Working on level 64 of 90 (22247 nonzero points found)
#    - Remaining points before horizontal spread: 0
#    - Remaining points before downward spread: 0
#  - Working on level 65 of 90 (21697 nonzero points found)
#    - Remaining points before horizontal spread: 0
#    - Remaining points before downward spread: 0
#  - Working on level 66 of 90 (21120 nonzero points found)
#    - Remaining points before horizontal spread: 0
#    - Remaining points before downward spread: 0
#  - Working on level 67 of 90 (20516 nonzero points found)
#    - Remaining points before horizontal spread: 0
#    - Remaining points before downward spread: 0
#  - Working on level 68 of 90 (19934 nonzero points found)
#    - Remaining points before horizontal spread: 0
#    - Remaining points before downward spread: 0
#  - Working on level 69 of 90 (19274 nonzero points found)
#    - Remaining points before horizontal spread: 0
#    - Remaining points before downward spread: 0
#  - Working on level 70 of 90 (18610 nonzero points found)
#    - Remaining points before horizontal spread: 0
#    - Remaining points before downward spread: 0
#  - Working on level 71 of 90 (17923 nonzero points found)
#    - Remaining points before horizontal spread: 0
#    - Remaining points before downward spread: 0
#  - Working on level 72 of 90 (17115 nonzero points found)
#    - Remaining points before horizontal spread: 0
#    - Remaining points before downward spread: 0
#  - Working on level 73 of 90 (16301 nonzero points found)
#    - Remaining points before horizontal spread: 0
#    - Remaining points before downward spread: 0
#  - Working on level 74 of 90 (15438 nonzero points found)
#    - Remaining points before horizontal spread: 0
#    - Remaining points before downward spread: 0
#  - Working on level 75 of 90 (14463 nonzero points found)
#    - Remaining points before horizontal spread: 0
#    - Remaining points before downward spread: 0
#  - Working on level 76 of 90 (13374 nonzero points found)
#    - Remaining points before horizontal spread: 0
#    - Remaining points before downward spread: 0
#  - Working on level 77 of 90 (12110 nonzero points found)
#    - Remaining points before horizontal spread: 0
#    - Remaining points before downward spread: 0
#  - Working on level 78 of 90 (10569 nonzero points found)
#    - Remaining points before horizontal spread: 0
#    - Remaining points before downward spread: 0
#  - Working on level 79 of 90 (7841 nonzero points found)
#    - Remaining points before horizontal spread: 0
#    - Remaining points before downward spread: 0
#  - Working on level 80 of 90 (4116 nonzero points found)
#    - Remaining points before horizontal spread: 0
#    - Remaining points before downward spread: 0

# %% [markdown]
# With this grid computed, we can now store it as a netCDF file which can be used later for all of our initial conditions:

# %%
interpolation_type_grid_C, source_row_grid_C, source_col_grid_C, source_level_grid_C = gridC
interpolation_type_grid_S, source_row_grid_S, source_col_grid_S, source_level_grid_S = gridS
interpolation_type_grid_W, source_row_grid_W, source_col_grid_W, source_level_grid_W = gridW

# %%
output_file = os.path.join(data_folder,'Chukchi_Sea_interpolation_grid.nc')
ecco_interp.write_interpolation_grid_to_nc(output_file,
                                   interpolation_type_grid_C, source_row_grid_C, source_col_grid_C, source_level_grid_C,
                                   interpolation_type_grid_S, source_row_grid_S, source_col_grid_S, source_level_grid_S,
                                   interpolation_type_grid_W, source_row_grid_W, source_col_grid_W, source_level_grid_W)

# %% [markdown]
# ### Step 8: Visualizing the Interpolation Grid

# %% [markdown]
# Now that we've computed our interpolation grid, let's have a peek at the results:

# %%
plt.figure(figsize=(10,10))

plt.subplot(2,2,1)
C = plt.pcolormesh(interpolation_type_grid_C[10,:,:])
cbar = plt.colorbar(C)
cbar.set_ticks([0,1,2])
cbar.set_ticklabels(['Not\nInterpolated','Bi-linear\nInterpolation','Hydrostatically\n"Spread"'])
plt.ylabel('Model Rows')
plt.title('Interpolation Type')

plt.subplot(2,2,2)
C = plt.pcolormesh(source_row_grid_C[10,:,:])
plt.colorbar(C)
plt.title('Source Row\n(used for spreading routine)')

plt.subplot(2,2,3)
C = plt.pcolormesh(source_col_grid_C[10,:,:])
plt.colorbar(C)
plt.xlabel('Model Columns')
plt.ylabel('Model Rows')
plt.title('Source Column\n(used for spreading routine)')

plt.subplot(2,2,4)
C = plt.pcolormesh(source_level_grid_C[10,:,:],vmin=0,vmax=81)
plt.colorbar(C)
plt.xlabel('Model Columns')
plt.title('Source Level\n(used for spreading routine)')

plt.tight_layout()

plt.show()

# %% [markdown]
# As we can see above, most of the cells in the regional domain will be filled by linear interpolation from the ECCO grid. However, in the areas near the coastline that were unresolved in the ECCO model, we fill these regions somehow. The approach taken here is to assume that the grid will be filled hydrostatically. In other words, we assume that the depth levels in the model will have roughly equal density and adjacent grid cells should have the same values. If spreading cannot occur horizontally, such as in the case of local minima in the bathymetry, the spreading is conducted vertically using the grid cell above (hence the source level grid is also stored). In the plot above, the source grid is all 0 since we are at the surface, but this is not true in general.
#
# This spreading routine is fairly expensive (as you will find if you run the cells above) so it useful to only do this one time - and this is the motivation for creating and saving this interpolation grid. Here, the source row, column, and level is stored so that, when spreading is necessary, the source locations are already identified and can be used readily.

# %% [markdown]
# With this interpolation grid in hand, we are ready to make our initial conditions.
